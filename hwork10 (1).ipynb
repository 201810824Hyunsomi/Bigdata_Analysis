# %% [markdown]
# 201810824 현소미

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=100, centers=4, cluster_std=0.60, random_state=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(X)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[[ 6.69786996e-01  3.59540802e+00]
#  [-2.02396992e+00  7.99569054e+00]
#  [ 1.43289271e+00  4.37679234e+00]
#  [ 1.06923853e+00  4.53068484e+00]
#  [ 1.71444449e+00  5.02521524e+00]
#  [ 7.43873988e-01  4.12240568e+00]
#  [-2.04363942e+00  4.06392123e+00]
#  [-6.78603291e-01  7.88799076e+00]
#  [-4.74920358e-02  5.47425256e+00]
#  [-1.46976488e+00  7.69183251e+00]
#  [-8.64176859e-01  6.86528639e+00]
#  [-1.84838498e+00  6.90859736e+00]
#  [-1.27182547e+00  7.13460392e+00]
#  [-9.34289778e-01  7.73253222e+00]
#  [-7.34157408e-01  7.44484466e+00]
#  [ 3.18515794e+00  8.90082233e-02]
#  [ 1.35139348e+00  2.06383637e+00]
#  [-9.70171483e-02  3.48456995e+00]
#  [-1.93150361e+00  2.93698060e+00]
#  [ 2.73890793e+00  1.56768168e-01]
#  [ 2.33812285e+00  3.43116792e+00]
#  [-1.93673697e+00  7.57276799e+00]
#  [-1.98885366e+00  3.24143178e+00]
#  [ 2.33466499e+00 -2.40825518e-02]
#  [ 4.38990142e-01  4.53592883e+00]
#  [-1.58597553e+00  2.51979529e+00]
#  [-3.73138797e-01  3.80619114e+00]
#  [ 7.67522789e-01  4.39759671e+00]
#  [ 2.94821884e+00  2.03519717e+00]
#  [ 2.76253526e+00  7.89708758e-01]
#  [ 1.65179125e+00  6.81931763e-01]
#  [-8.73116904e-01  6.87422542e+00]
#  [ 2.16172321e+00  6.56595098e-01]
#  [ 2.06156753e+00  1.96918596e+00]
#  [-1.15845639e+00  3.47120626e+00]
#  [ 1.16411070e+00  3.79132988e+00]
#  [-1.54707525e+00  8.99317925e+00]
#  [ 1.81336135e+00  1.63113070e+00]
#  [ 4.96857948e-02  8.63737679e+00]
#  [-1.97375691e+00  2.42201914e+00]
#  [ 1.06269622e+00  5.17635143e+00]
#  [-1.42689992e+00  3.29890112e+00]
#  [-1.63442682e+00  6.50141812e+00]
#  [-2.07459735e+00  3.58809203e+00]
#  [-1.94364473e+00  2.82810154e+00]
#  [-1.98351709e+00  8.34207780e+00]
#  [ 1.53278923e+00  5.50353861e-01]
#  [-1.90841166e+00  3.32374224e+00]
#  [ 6.70478769e-01  4.04094275e+00]
#  [ 4.43598630e-01  3.11530945e+00]
#  [ 2.24592863e-01  4.77028154e+00]
#  [ 1.86833600e+00  9.31362865e-01]
#  [-1.18094952e+00  2.79290301e+00]
#  [-1.78799614e+00  4.02744050e+00]
#  [-8.50922460e-01  2.26992336e+00]
#  [-1.26285145e+00  7.39264147e+00]
#  [-7.85181444e-01  8.32956251e+00]
#  [ 2.49272186e+00  9.75053406e-01]
#  [ 2.26908736e+00  1.32160756e+00]
#  [-5.35437899e-01  8.02562558e+00]
#  [-1.46065212e+00  7.01048924e+00]
#  [ 1.41281595e+00  1.53033470e+00]
#  [ 2.13141478e+00  1.13885728e+00]
#  [ 1.89593761e+00  5.18540259e+00]
#  [ 1.29297652e+00  1.47930168e+00]
#  [-5.88460017e-01  8.22861825e+00]
#  [-2.31644846e+00  2.64093150e+00]
#  [-1.28929999e+00  2.26204536e+00]
#  [ 2.18023251e+00  1.48364708e+00]
#  [ 1.24258802e+00  4.50399192e+00]
#  [-1.86880148e+00  8.24441673e+00]
#  [ 1.35617762e+00  1.43815955e+00]
#  [ 9.14338767e-01  4.55014643e+00]
#  [-1.52157528e+00  7.84594751e+00]
#  [ 1.00372519e+00  4.19147702e+00]
#  [ 1.49493180e+00  3.85848832e+00]
#  [-4.06368637e-01  3.46150906e+00]
#  [-1.68770604e+00  3.39935610e+00]
#  [ 2.29667251e+00  4.86777605e-01]
#  [ 1.07714851e+00  1.17533301e+00]
#  [ 1.56737975e+00 -1.38105901e-01]
#  [-1.69199357e+00  8.76126877e+00]
#  [-1.34796111e+00  3.71371380e+00]
#  [ 7.93137001e-03  4.17614316e+00]
#  [ 1.67467427e+00  6.80018960e-01]
#  [-9.58552833e-01  2.82487621e+00]
#  [ 1.51088850e+00  9.28830897e-01]
#  [ 1.80709613e+00  4.49190773e-01]
#  [ 1.87271752e+00  4.18069237e+00]
#  [ 1.01618041e+00  4.48527047e+00]
#  [ 9.59360742e-01  4.56078645e+00]
#  [-1.30104869e+00  2.25824179e+00]
#  [ 3.47138300e-01  3.45177657e+00]
#  [-1.12352716e+00  3.16235936e+00]
#  [-2.42165857e+00  3.18151728e+00]
#  [-1.91088578e+00  7.86675906e+00]
#  [-1.73030157e+00  7.42173015e+00]
#  [-1.56784898e+00  3.94588789e+00]
#  [-6.95740480e-01  8.02669661e+00]
#  [-5.55523811e-01  4.69595848e+00]]
# </div>

# %%
print(y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0 3 0 0 0 0 2 3 0 3 3 3 3 3 3 1 1 2 2 1 0 3 2 1 0 2 2 0 1 1 1 3 1 1 2 0 3
#  1 3 2 0 2 3 2 2 3 1 2 0 0 0 1 2 2 2 3 3 1 1 3 3 1 1 0 1 3 2 2 1 0 3 1 0 3
#  0 0 2 2 1 1 1 3 2 0 1 2 1 1 0 0 0 2 0 2 2 3 3 2 3 0]
# </div>

# %%
def normDist(x1, x2):
    #dist=np.sqrt(sum(np.power(x1 - x2, 2))) #36.406001444695193
    dist = np.linalg.norm(x1 - x2) #36.406001444695193
    return dist
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def cluster(x, k, centroids):
    row, col = x.shape
    clusterAssigned = np.zeros(shape=(row, k), dtype=float)
    # print (clusterAssigned)
    clusterUpdated=True
    iter = 1
    while(clusterUpdated):
        print ("\n\n====== Iteration {} ======".format(iter))
        # STEP 1: assign to closer cluster
        for i in range(row):
            minDist = np.inf   # set arbitray max to minDist
            minIndex = -1      # set arbitray index to minIndex
            # compute distance and assign to closer cluster
            for j in range(k):
                # distance from centroids[j] to x[0]
                distJI = normDist(centroids[j], x[i])
                # print ("Distance {:.3f} between {} and {}".format(distJI, centroids[j], x[i]))
                # pick the closest centroid
                if distJI < minDist:
                    minDist = distJI
                    minIndex = j
            print (".....Assigning {} to {}th centroid by {:.3f}".format(x[i], minIndex, minDist))
            clusterAssigned[i] = [minIndex, minDist]   #-----changed
        print ("\n.....Assigned clusters: \n {}".format(clusterAssigned))
        # STEP 2: update centroids
        _centroids=np.zeros(shape = (k, x.shape[1]), dtype=float)
        for cent in range(k):
            # read data by index and average them
            _centroids[cent] = np.mean(x[clusterAssigned[:,0]==cent],axis=0)
        # print ("Centroids updated: \n", _centroids)
        # STEP 3: see if centroids is updated. STOP if NOT updated
        comparison = np.equal(centroids, _centroids) # np.isclose() in case some tolerence is required
        if(comparison.all() == True):
            print ("\n.....NOT Updating Centroids\n {} => \n{}".format(centroids, _centroids))
            clusterUpdated = False
            return centroids, clusterAssigned
        else:
            print ("\n.....Updating Centroids\n {} => \n{}".format(centroids, _centroids))
            centroids = _centroids
            iter += 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np
centroids = np.array([[ 6.69786996e-01,  3.59540802e+00],[-2.02396992e+00,  7.99569054e+00]], dtype = float)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cluster(X,2,centroids)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#
# ====== Iteration 1 ======
# .....Assigning [0.669787   3.59540802] to 0th centroid by 0.000
# .....Assigning [-2.02396992  7.99569054] to 1th centroid by 0.000
# .....Assigning [1.43289271 4.37679234] to 0th centroid by 1.092
# .....Assigning [1.06923853 4.53068484] to 0th centroid by 1.017
# .....Assigning [1.71444449 5.02521524] to 0th centroid by 1.771
# .....Assigning [0.74387399 4.12240568] to 0th centroid by 0.532
# .....Assigning [-2.04363942  4.06392123] to 0th centroid by 2.754
# .....Assigning [-0.67860329  7.88799076] to 1th centroid by 1.350
# .....Assigning [-0.04749204  5.47425256] to 0th centroid by 2.011
# .....Assigning [-1.46976488  7.69183251] to 1th centroid by 0.632
# .....Assigning [-0.86417686  6.86528639] to 1th centroid by 1.620
# .....Assigning [-1.84838498  6.90859736] to 1th centroid by 1.101
# .....Assigning [-1.27182547  7.13460392] to 1th centroid by 1.143
# .....Assigning [-0.93428978  7.73253222] to 1th centroid by 1.121
# .....Assigning [-0.73415741  7.44484466] to 1th centroid by 1.403
# .....Assigning [3.18515794 0.08900822] to 0th centroid by 4.315
# .....Assigning [1.35139348 2.06383637] to 0th centroid by 1.676
# .....Assigning [-0.09701715  3.48456995] to 0th centroid by 0.775
# .....Assigning [-1.93150361  2.9369806 ] to 0th centroid by 2.683
# .....Assigning [2.73890793 0.15676817] to 0th centroid by 4.013
# .....Assigning [2.33812285 3.43116792] to 0th centroid by 1.676
# .....Assigning [-1.93673697  7.57276799] to 1th centroid by 0.432
# .....Assigning [-1.98885366  3.24143178] to 0th centroid by 2.682
# .....Assigning [ 2.33466499 -0.02408255] to 0th centroid by 3.984
# .....Assigning [0.43899014 4.53592883] to 0th centroid by 0.968
# .....Assigning [-1.58597553  2.51979529] to 0th centroid by 2.499
# .....Assigning [-0.3731388   3.80619114] to 0th centroid by 1.064
# .....Assigning [0.76752279 4.39759671] to 0th centroid by 0.808
# .....Assigning [2.94821884 2.03519717] to 0th centroid by 2.761
# .....Assigning [2.76253526 0.78970876] to 0th centroid by 3.500
# .....Assigning [1.65179125 0.68193176] to 0th centroid by 3.075
# .....Assigning [-0.8731169   6.87422542] to 1th centroid by 1.607
# .....Assigning [2.16172321 0.6565951 ] to 0th centroid by 3.296
# .....Assigning [2.06156753 1.96918596] to 0th centroid by 2.140
# .....Assigning [-1.15845639  3.47120626] to 0th centroid by 1.832
# .....Assigning [1.1641107  3.79132988] to 0th centroid by 0.532
# .....Assigning [-1.54707525  8.99317925] to 1th centroid by 1.106
# .....Assigning [1.81336135 1.6311307 ] to 0th centroid by 2.273
# .....Assigning [0.04968579 8.63737679] to 1th centroid by 2.171
# .....Assigning [-1.97375691  2.42201914] to 0th centroid by 2.892
# .....Assigning [1.06269622 5.17635143] to 0th centroid by 1.629
# .....Assigning [-1.42689992  3.29890112] to 0th centroid by 2.118
# .....Assigning [-1.63442682  6.50141812] to 1th centroid by 1.544
# .....Assigning [-2.07459735  3.58809203] to 0th centroid by 2.744
# .....Assigning [-1.94364473  2.82810154] to 0th centroid by 2.724
# .....Assigning [-1.98351709  8.3420778 ] to 1th centroid by 0.349
# .....Assigning [1.53278923 0.55035386] to 0th centroid by 3.165
# .....Assigning [-1.90841166  3.32374224] to 0th centroid by 2.592
# .....Assigning [0.67047877 4.04094275] to 0th centroid by 0.446
# .....Assigning [0.44359863 3.11530945] to 0th centroid by 0.531
# .....Assigning [0.22459286 4.77028154] to 0th centroid by 1.256
# .....Assigning [1.868336   0.93136287] to 0th centroid by 2.921
# .....Assigning [-1.18094952  2.79290301] to 0th centroid by 2.017
# .....Assigning [-1.78799614  4.0274405 ] to 0th centroid by 2.495
# .....Assigning [-0.85092246  2.26992336] to 0th centroid by 2.017
# .....Assigning [-1.26285145  7.39264147] to 1th centroid by 0.971
# .....Assigning [-0.78518144  8.32956251] to 1th centroid by 1.283
# .....Assigning [2.49272186 0.97505341] to 0th centroid by 3.192
# .....Assigning [2.26908736 1.32160756] to 0th centroid by 2.780
# .....Assigning [-0.5354379   8.02562558] to 1th centroid by 1.489
# .....Assigning [-1.46065212  7.01048924] to 1th centroid by 1.135
# .....Assigning [1.41281595 1.5303347 ] to 0th centroid by 2.195
# .....Assigning [2.13141478 1.13885728] to 0th centroid by 2.858
# .....Assigning [1.89593761 5.18540259] to 0th centroid by 2.008
# .....Assigning [1.29297652 1.47930168] to 0th centroid by 2.206
# .....Assigning [-0.58846002  8.22861825] to 1th centroid by 1.454
# .....Assigning [-2.31644846  2.6409315 ] to 0th centroid by 3.135
# .....Assigning [-1.28929999  2.26204536] to 0th centroid by 2.370
# .....Assigning [2.18023251 1.48364708] to 0th centroid by 2.596
# .....Assigning [1.24258802 4.50399192] to 0th centroid by 1.074
# .....Assigning [-1.86880148  8.24441673] to 1th centroid by 0.293
# .....Assigning [1.35617762 1.43815955] to 0th centroid by 2.264
# .....Assigning [0.91433877 4.55014643] to 0th centroid by 0.986
# .....Assigning [-1.52157528  7.84594751] to 1th centroid by 0.524
# .....Assigning [1.00372519 4.19147702] to 0th centroid by 0.683
# .....Assigning [1.4949318  3.85848832] to 0th centroid by 0.866
# .....Assigning [-0.40636864  3.46150906] to 0th centroid by 1.084
# .....Assigning [-1.68770604  3.3993561 ] to 0th centroid by 2.366
# .....Assigning [2.29667251 0.48677761] to 0th centroid by 3.509
# .....Assigning [1.07714851 1.17533301] to 0th centroid by 2.454
# .....Assigning [ 1.56737975 -0.1381059 ] to 0th centroid by 3.840
# .....Assigning [-1.69199357  8.76126877] to 1th centroid by 0.834
# .....Assigning [-1.34796111  3.7137138 ] to 0th centroid by 2.021
# .....Assigning [0.00793137 4.17614316] to 0th centroid by 0.881
# .....Assigning [1.67467427 0.68001896] to 0th centroid by 3.084
# .....Assigning [-0.95855283  2.82487621] to 0th centroid by 1.801
# .....Assigning [1.5108885 0.9288309] to 0th centroid by 2.796
# .....Assigning [1.80709613 0.44919077] to 0th centroid by 3.345
# .....Assigning [1.87271752 4.18069237] to 0th centroid by 1.338
# .....Assigning [1.01618041 4.48527047] to 0th centroid by 0.955
# .....Assigning [0.95936074 4.56078645] to 0th centroid by 1.008
# .....Assigning [-1.30104869  2.25824179] to 0th centroid by 2.382
# .....Assigning [0.3471383  3.45177657] to 0th centroid by 0.353
# .....Assigning [-1.12352716  3.16235936] to 0th centroid by 1.845
# .....Assigning [-2.42165857  3.18151728] to 0th centroid by 3.119
# .....Assigning [-1.91088578  7.86675906] to 1th centroid by 0.171
# .....Assigning [-1.73030157  7.42173015] to 1th centroid by 0.645
# .....Assigning [-1.56784898  3.94588789] to 0th centroid by 2.265
# .....Assigning [-0.69574048  8.02669661] to 1th centroid by 1.329
# .....Assigning [-0.55552381  4.69595848] to 0th centroid by 1.647
#
# .....Assigned clusters:
#  [[0.00000000e+00 3.02506151e-09]
#  [1.00000000e+00 2.80946348e-09]
#  [0.00000000e+00 1.09219586e+00]
#  [0.00000000e+00 1.01700750e+00]
#  [0.00000000e+00 1.77077891e+00]
#  [0.00000000e+00 5.32179869e-01]
#  [0.00000000e+00 2.75357723e+00]
#  [1.00000000e+00 1.34967056e+00]
#  [0.00000000e+00 2.01110567e+00]
#  [1.00000000e+00 6.32038711e-01]
#  [1.00000000e+00 1.61954731e+00]
#  [1.00000000e+00 1.10118194e+00]
#  [1.00000000e+00 1.14332474e+00]
#  [1.00000000e+00 1.12100630e+00]
#  [1.00000000e+00 1.40251471e+00]
#  [0.00000000e+00 4.31531349e+00]
#  [0.00000000e+00 1.67639468e+00]
#  [0.00000000e+00 7.74773304e-01]
#  [0.00000000e+00 2.68332620e+00]
#  [0.00000000e+00 4.01316652e+00]
#  [0.00000000e+00 1.67640071e+00]
#  [1.00000000e+00 4.31825280e-01]
#  [0.00000000e+00 2.68210166e+00]
#  [0.00000000e+00 3.98403448e+00]
#  [0.00000000e+00 9.68424790e-01]
#  [0.00000000e+00 2.49908129e+00]
#  [0.00000000e+00 1.06401303e+00]
#  [0.00000000e+00 8.08120646e-01]
#  [0.00000000e+00 2.76143252e+00]
#  [0.00000000e+00 3.50022052e+00]
#  [0.00000000e+00 3.07452049e+00]
#  [1.00000000e+00 1.60690593e+00]
#  [0.00000000e+00 3.29582995e+00]
#  [0.00000000e+00 2.14047
